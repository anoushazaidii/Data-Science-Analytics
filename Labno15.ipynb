# %% [markdown]
# <a href="https://colab.research.google.com/github/anoushazaidii/Data-Science-Analytics/blob/main/Labno15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tests as t

# %matplotlib inline

# Read in the datasets
movies = pd.read_csv('/content/movies.csv')
ratings = pd.read_csv('/content/ratings.csv')

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movie = movies.loc[:,["movieId","title"]]
movie.head(10)
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)

# %%
rating = ratings.loc[:,["userId","movieId","rating"]]
rating.head(10)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
# then merge movie and rating data
data = pd.merge(movie,rating)

# %%
# now lets look at our data
data.head(10)
# Out:
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5
# 5        1  Toy Story (1995)      18     3.5
# 6        1  Toy Story (1995)      19     4.0
# 7        1  Toy Story (1995)      21     3.5
# 8        1  Toy Story (1995)      27     3.0
# 9        1  Toy Story (1995)      31     5.0

# %%
data = data.iloc[:10000,:]

# %%
# lets make a pivot table in order to make rows are users and columns are movies. And values are rating
pivot_table = data.pivot_table(index = ["userId"],columns = ["title"],values = "rating")
pivot_table.head(10)
# Out:
# title   Ace Ventura: Pet Detective (1994)  \
# userId
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     3.0
# 6                                     3.0
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
#
# title   Ace Ventura: When Nature Calls (1995)  Addiction, The (1995)  \
# userId
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# 5                                         NaN                    NaN
# ...

# %%
movie_watched = pivot_table["Ace Ventura: Pet Detective (1994)"]
similarity_with_other_movies = pivot_table.corrwith(movie_watched)
similarity_with_other_movies = similarity_with_other_movies.sort_values(ascending=False)
similarity_with_other_movies.head(20)
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2845: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2704: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# title
# Poison Ivy II (1996)                                                               1.000000
# Eye for an Eye (1996)                                                              1.000000
# Losing Isaiah (1995)                                                               1.000000
# Love Affair (1994)                                                                 1.000000
# Only You (1994)                                                                    1.000000
# Antonia's Line (Antonia) (1995)                                                    1.000000
# Crooklyn (1994)                                                                    1.000000
# ...

# %% [markdown]
#   Here we can conclude that we can recommend Things to Do in Denver When You're Dead (1995) to the people who watched Ace Ventura: Pet Detective (1994)
